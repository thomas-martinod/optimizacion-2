# %% [markdown]
# ### Problem 1
# Plotting the function $f(x) = f(x_1, x_2) = x_1 e^{-{x_1}^2 - {x_2}^2}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function f
def f(x1, x2):
    return x1 * np.exp(-(x1**2 + x2**2))

# Create a grid of x1 and x2 values
x1 = np.linspace(-5, 5, 100)
x2 = np.linspace(-5, 5, 100)
X1, X2 = np.meshgrid(x1, x2)
Z = f(X1, X2)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surface = ax.plot_surface(X1, X2, Z, cmap='viridis')

# Set labels
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$f(x_1, x_2)$', labelpad=10)  # Adjust labelpad to change the distance of the Z label

# Set title with modern math fonts in LaTeX-like format
plt.title(r'$f(x) = x_1 e^{-{x_1}^2 - {x_2}^2}$', fontsize=14, family='Serif')

# Show the plot
plt.show()

# %% [markdown]
# ### Problem 2
# Plotting the function $f(x, y) = (x-2)^2 + (y-2)^2$ with the constrains $x+y \geq 4$ and $2x-y \geq 0$.

# %%
# Define the function f(x, y)
def f(x, y):
    return (x - 2)**2 + (y - 2)**2

# Create a grid of x and y values
x = np.linspace(0, 4, 400)
y = np.linspace(0, 4, 400)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Define the constraint functions
constraint1 = x + y - 4
constraint2 = 2*x - y

# Create a contour plot for the function
plt.contour(X, Y, Z, levels=np.linspace(0, 8, 20), cmap='viridis')

# Fill the region satisfying the constraints
plt.fill_between(x, x-4, color='gray', alpha=0.5, label='Feasible Region')
plt.fill_between(x, 2*x, color='gray', alpha=0.5)

# Add labels and legend
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# Show the plot
plt.title(r'2D Proyection of $f(x, y) = (x-2)^2 + (y-2)^2$')
plt.grid(True)
plt.show()

# %%
# Create a grid of x and y values
x = np.linspace(0, 4, 100)
y = np.linspace(0, 4, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Define the constraint functions
constraint1 = x + y - 4
constraint2 = 2*x - y

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface of the function
surf = ax.plot_surface(X, Y, Z, cmap='viridis')

# Add the constraints as planes
X_plane, Y_plane = np.meshgrid(x, y)
Z_plane1 = np.maximum(X_plane + Y_plane - 4, 0)
Z_plane2 = np.maximum(2*X_plane - Y_plane, 0)
ax.plot_surface(X_plane, Y_plane, Z_plane1, alpha=0.5, color='gray', label=r'$x+y\geq 4$')
ax.plot_surface(X_plane, Y_plane, Z_plane2, alpha=0.5, color='gray', label=r'$2x-y\geq 0$')

# Set labels and legend
ax.set_xlabel('x')
ax.set_ylabel('y')

# Show the plot
plt.title('3D plot of $f(x, y) = (x-2)^2 + (y-2)^2$ with constrains')
plt.show()
